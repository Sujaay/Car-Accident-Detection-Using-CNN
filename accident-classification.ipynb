# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from time import perf_counter 
import os
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from tensorflow.keras.utils import plot_model

# %% [markdown]
# ## Defining batch specfications

# %%
batch_size = 100
img_height = 250
img_width = 250

# %% [markdown]
# ## Loading training set

# %%
training_data = tf.keras.preprocessing.image_dataset_from_directory(
    'data/train',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 3052 files belonging to 2 classes.

# %% [markdown]
# ## Loading validation dataset

# %%
validation_data =  tf.keras.preprocessing.image_dataset_from_directory(
    'data/val',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 98 files belonging to 2 classes.

# %% [markdown]
# ## Loading testing dataset

# %%
testing_data = tf.keras.preprocessing.image_dataset_from_directory(
    'data/test',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 100 files belonging to 2 classes.

# %%
testing_data
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 250, 250, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
class_names = training_data.class_names
class_names
# Out:
# ['Accident', 'Non Accident']

# %% [markdown]
# ## Configuring dataset for performance

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
training_data = training_data.cache().prefetch(buffer_size=AUTOTUNE)
testing_data = testing_data.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Building the CNN

# %%
model = tf.keras.models.Sequential([
  layers.BatchNormalization(),
  layers.Conv2D(32, 3, activation='relu'), # Conv2D(f_size, filter_size, activation) # relu, sigmoid, softmax
  layers.MaxPooling2D(), # MaxPooling
  layers.Conv2D(64, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(256, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(512, activation='relu'),
  layers.Dense(len(class_names), activation= 'softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.build((None, 250, 250, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 250, 250, 3)      12
#  ormalization)
#
#  conv2d (Conv2D)             (None, 248, 248, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 124, 124, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 122, 122, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 61, 61, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 59, 59, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 29, 29, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 27, 27, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 43264)             0
#
#  dense (Dense)               (None, 512)               22151680
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 22,541,134
# Trainable params: 22,541,128
# Non-trainable params: 6
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ## Training the CNN

# %%
checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
history = model.fit(training_data, validation_data=validation_data, epochs = 20, callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 31/31 [==============================] - ETA: 0s - loss: 1.3908 - accuracy: 0.6828
# Epoch 1: val_accuracy improved from -inf to 0.45918, saving model to model_weights.h5
# 31/31 [==============================] - 128s 4s/step - loss: 1.3908 - accuracy: 0.6828 - val_loss: 1.5973 - val_accuracy: 0.4592
# Epoch 2/20
# 31/31 [==============================] - ETA: 0s - loss: 0.3193 - accuracy: 0.8571
# Epoch 2: val_accuracy improved from 0.45918 to 0.46939, saving model to model_weights.h5
# 31/31 [==============================] - 127s 4s/step - loss: 0.3193 - accuracy: 0.8571 - val_loss: 1.9718 - val_accuracy: 0.4694
# Epoch 3/20
# 31/31 [==============================] - ETA: 0s - loss: 0.2133 - accuracy: 0.8968
# Epoch 3: val_accuracy improved from 0.46939 to 0.55102, saving model to model_weights.h5
# 31/31 [==============================] - 132s 4s/step - loss: 0.2133 - accuracy: 0.8968 - val_loss: 1.0776 - val_accuracy: 0.5510
# Epoch 4/20
# 31/31 [==============================] - ETA: 0s - loss: 0.1764 - accuracy: 0.9145
# Epoch 4: val_accuracy improved from 0.55102 to 0.73469, saving model to model_weights.h5
# 31/31 [==============================] - 136s 4s/step - loss: 0.1764 - accuracy: 0.9145 - val_loss: 0.5984 - val_accuracy: 0.7347
# Epoch 5/20
# 31/31 [==============================] - ETA: 0s - loss: 0.1367 - accuracy: 0.9368
# Epoch 5: val_accuracy improved from 0.73469 to 0.79592, saving model to model_weights.h5
# 31/31 [==============================] - 138s 4s/step - loss: 0.1367 - accuracy: 0.9368 - val_loss: 0.4033 - val_accuracy: 0.7959
# Epoch 6/20
# 31/31 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9522
# Epoch 6: val_accuracy improved from 0.79592 to 0.83673, saving model to model_weights.h5
# 31/31 [==============================] - 157s 5s/step - loss: 0.1132 - accuracy: 0.9522 - val_loss: 0.3445 - val_accuracy: 0.8367
# Epoch 7/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9597
# Epoch 7: val_accuracy improved from 0.83673 to 0.91837, saving model to model_weights.h5
# 31/31 [==============================] - 155s 5s/step - loss: 0.0918 - accuracy: 0.9597 - val_loss: 0.2387 - val_accuracy: 0.9184
# Epoch 8/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0788 - accuracy: 0.9666
# Epoch 8: val_accuracy improved from 0.91837 to 0.92857, saving model to model_weights.h5
# 31/31 [==============================] - 154s 5s/step - loss: 0.0788 - accuracy: 0.9666 - val_loss: 0.2338 - val_accuracy: 0.9286
# Epoch 9/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0700 - accuracy: 0.9676
# Epoch 9: val_accuracy did not improve from 0.92857
# 31/31 [==============================] - 152s 5s/step - loss: 0.0700 - accuracy: 0.9676 - val_loss: 0.2222 - val_accuracy: 0.9286
# Epoch 10/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9771
# Epoch 10: val_accuracy did not improve from 0.92857
# 31/31 [==============================] - 181s 6s/step - loss: 0.0598 - accuracy: 0.9771 - val_loss: 0.2546 - val_accuracy: 0.8878
# Epoch 11/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9764
# Epoch 11: val_accuracy did not improve from 0.92857
# 31/31 [==============================] - 190s 6s/step - loss: 0.0643 - accuracy: 0.9764 - val_loss: 0.2028 - val_accuracy: 0.9184
# Epoch 12/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0467 - accuracy: 0.9813
# Epoch 12: val_accuracy did not improve from 0.92857
# 31/31 [==============================] - 191s 6s/step - loss: 0.0467 - accuracy: 0.9813 - val_loss: 0.1741 - val_accuracy: 0.9184
# Epoch 13/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9830
# Epoch 13: val_accuracy did not improve from 0.92857
# 31/31 [==============================] - 181s 6s/step - loss: 0.0428 - accuracy: 0.9830 - val_loss: 0.1563 - val_accuracy: 0.9286
# Epoch 14/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9833
# Epoch 14: val_accuracy did not improve from 0.92857
# 31/31 [==============================] - 165s 5s/step - loss: 0.0462 - accuracy: 0.9833 - val_loss: 0.2504 - val_accuracy: 0.9082
# Epoch 15/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9807
# Epoch 15: val_accuracy improved from 0.92857 to 0.93878, saving model to model_weights.h5
# 31/31 [==============================] - 153s 5s/step - loss: 0.0489 - accuracy: 0.9807 - val_loss: 0.2773 - val_accuracy: 0.9388
# Epoch 16/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0302 - accuracy: 0.9885
# Epoch 16: val_accuracy did not improve from 0.93878
# 31/31 [==============================] - 163s 5s/step - loss: 0.0302 - accuracy: 0.9885 - val_loss: 0.1937 - val_accuracy: 0.9184
# Epoch 17/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9905
# Epoch 17: val_accuracy did not improve from 0.93878
# 31/31 [==============================] - 144s 5s/step - loss: 0.0315 - accuracy: 0.9905 - val_loss: 0.1589 - val_accuracy: 0.9286
# Epoch 18/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0451 - accuracy: 0.9859
# Epoch 18: val_accuracy did not improve from 0.93878
# 31/31 [==============================] - 149s 5s/step - loss: 0.0451 - accuracy: 0.9859 - val_loss: 0.1578 - val_accuracy: 0.9184
# Epoch 19/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9925
# Epoch 19: val_accuracy did not improve from 0.93878
# 31/31 [==============================] - 142s 5s/step - loss: 0.0203 - accuracy: 0.9925 - val_loss: 0.2275 - val_accuracy: 0.9286
# Epoch 20/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9934
# Epoch 20: val_accuracy did not improve from 0.93878
# 31/31 [==============================] - 135s 4s/step - loss: 0.0181 - accuracy: 0.9934 - val_loss: 0.2500 - val_accuracy: 0.9184

# %% [markdown]
# ## Serializing the model structure to JSON

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# ## Plotting the statistics of the training data (a)

# %%
plt.plot(history.history['loss'], label = 'training loss')
plt.plot(history.history['accuracy'], label = 'training accuracy')
plt.grid(True)
plt.legend()

# %% [markdown]
# ## Plotting the statistics of the validation data (b)

# %%
plt.plot(history.history['val_loss'], label = 'validation loss')
plt.plot(history.history['val_accuracy'], label = 'validation accuracy')
plt.grid(True)
plt.legend()

# %% [markdown]
# ## Visualizing the results on testing data

# %%
AccuracyVector = []
plt.figure(figsize=(30, 30))
for images, labels in testing_data.take(1):
    predictions = model.predict(images)
    predlabel = []
    prdlbl = []
    
    for mem in predictions:
        predlabel.append(class_names[np.argmax(mem)])
        prdlbl.append(np.argmax(mem))
    
    AccuracyVector = np.array(prdlbl) == labels
    for i in range(40):
        ax = plt.subplot(10, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title('Pred: '+ predlabel[i]+' actl:'+class_names[labels[i]] )
        plt.axis('off')
        plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-983c23fb64d6> in <cell line: 2>()
#       1 AccuracyVector = []
# ----> 2 plt.figure(figsize=(30, 30))
#       3 for images, labels in testing_data.take(1):
#       4     predictions = model.predict(images)
#       5     predlabel = []
#
# NameError: name 'plt' is not defined
